# %%
type_map = expand_for_types(
    "RepositoryObject",
    target_types=[
        "Person",
        "PeopleAudience",
        "Organization",
        "Place",
        "DefinedTerm",
        "CreativeWork",
    ],
    sample=200,  # optional fast scan
)
