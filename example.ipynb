# %% [markdown]
# # Example Code

# %% [markdown]
# ## Importing packages

# %%
from src.tabulator import LDaCATabulator

# %% [markdown]
# ## Downloading corpus and decompress the folder

# %%
zip_url = "https://data.ldaca.edu.au/api/object/arcp%3A%2F%2Fname%2Chdl10.26180~23961609.zip"

ldac_tb = LDaCATabulator(zip_url)
# Out:
# 100%|██████████| 8078/8078 [00:07<00:00, 1038.60it/s]

# %% [markdown]
# ## Getting metadata and text data

# %%
text_data = ldac_tb.get_text()
text_data
# Out:
# 100%|██████████| 1354/1354 [01:30<00:00, 14.98it/s]
#                                            name author_@type  \
# 0                Text 1-001 1788 Philip, Arthur       Person
# 1                Text 1-002 1788 Philip, Arthur       Person
# 2                Text 1-003 1788 Philip, Arthur       Person
# 3                Text 1-004 1788 Philip, Arthur       Person
# 4                Text 1-005 1788 Philip, Arthur       Person
# ...                                         ...          ...
# 1349             Text 4-421 1897 Turner, George       Person
# 1350         Text 4-422 1898 Lyne, William John       Person
# 1351       Text 4-423 1898 Downer, John William       Person
# 1352  Text 4-424 1898 Kingston, Charles Cameron       Person
# 1353    Text 4-425 1895 Paterson, Andrew Barton       Person
#
#                                             author_name author_birthDate  \
# 0              Philip, Arthur - status 1788 text #1-001             1738
# 1              Philip, Arthur - status 1788 text #1-002             1738
# 2              Philip, Arthur - status 1788 text #1-003             1738
# 3              Philip, Arthur - status 1788 text #1-004             1738
# 4              Philip, Arthur - status 1788 text #1-005             1738
# ...                                                 ...              ...
# 1349           Turner, George - status 1897 text #4-421             1851
# 1350       Lyne, William John - status 1898 text #4-422             1844
# 1351     Downer, John William - status 1898 text #4-423             1844
# 1352  Kingston, Charles Cameron - status 1898 text #...             1850
# 1353  Paterson, Andrew Barton - status 1895 text #4-425             1864
#
#      author_local:birthDateEstimateStart author_local:birthDateEstimateEnd  \
# 0                                   1738                              1738
# 1                                   1738                              1738
# 2                                   1738                              1738
# 3                                   1738                              1738
# 4                                   1738                              1738
# ...                                  ...                               ...
# 1349                                1851                              1851
# 1350                                1844                              1844
# 1351                                1844                              1844
# 1352                                1850                              1850
# 1353                                1864                              1864
#
#       author_birthPlace author_gender author_local:arrivalDate  \
# 0         Great Britain             m                     1788
# 1         Great Britain             m                     1788
# 2         Great Britain             m                     1788
# 3         Great Britain             m                     1788
# 4         Great Britain             m                     1788
# ...                 ...           ...                      ...
# 1349           Victoria             m                     None
# 1350  Van Diemen's Land             m                     None
# 1351    South Australia             m                     None
# 1352    South Australia             m                     None
# 1353    New South Wales             m                     None
#
#      author_local:arrivalDateEstimateStart  ...  \
# 0                                     1788  ...
# 1                                     1788  ...
# 2                                     1788  ...
# 3                                     1788  ...
# 4                                     1788  ...
# ...                                    ...  ...
# 1349                                  1851  ...
# 1350                                  1844  ...
# 1351                                  1844  ...
# 1352                                  1850  ...
# 1353                                  1864  ...
#
#      ldac:indexableText_materialType  \
# 0                    DerivedMaterial
# 1                    DerivedMaterial
# 2                    DerivedMaterial
# 3                    DerivedMaterial
# 4                    DerivedMaterial
# ...                              ...
# 1349                 DerivedMaterial
# 1350                 DerivedMaterial
# 1351                 DerivedMaterial
# 1352                 DerivedMaterial
# 1353                 DerivedMaterial
#
#               ldac:indexableText_ldac:annotationOf  \
# 0                               Niall, 1998 p10-11
# 1                               Niall, 1998 p12-13
# 2                               Clark, 1977 p44-46
# 3                               Clark, 1977 p47-48
# 4                                  Clark, 1977 p52
# ...                                            ...
# 1349  Federation Debates Adelaide, March 24 p37-50
# 1350  Federation Debates Melbourne, Jan 24 p95-102
# 1351  Federation Debates Melbourne, Jan 24 p112-16
# 1352   Federation Debates Melbourne, Jan 24 p91-95
# 1353                                Paterson, 1895
#
#      ldac:indexableText_inLanguage ldac:indexableText_encodingFormat  \
# 0                          English                        text/plain
# 1                          English                        text/plain
# 2                          English                        text/plain
# 3                          English                        text/plain
# 4                          English                        text/plain
# ...                            ...                               ...
# 1349                       English                        text/plain
# 1350                       English                        text/plain
# 1351                       English                        text/plain
# 1352                       English                        text/plain
# 1353                       English                        text/plain
#
#      ldac:indexableText_encodingFormat_1  \
# 0
# 1
# 2
# 3
# 4
# ...                                  ...
# 1349
# 1350
# 1351
# 1352
# 1353
#
#      ldac:indexableText_ldac:communicationMode ldac:indexableText_contentSize  \
# 0                              WrittenLanguage                           4960
# 1                              WrittenLanguage                           3342
# 2                              WrittenLanguage                           3339
# 3                              WrittenLanguage                           4738
# 4                              WrittenLanguage                           1825
# ...                                        ...                            ...
# 1349                            SpokenLanguage                          48257
# 1350                            SpokenLanguage                          28080
# 1351                            SpokenLanguage                          13818
# 1352                            SpokenLanguage                          15562
# 1353                           WrittenLanguage                            760
#
#                                           ldac:mainText  \
# 0     <source><g=m><o=b><age=50><status=1><abode=00>...
# 1     \n\n\n<source><g=m><o=b><age=50><status=1><abo...
# 2     \n\n\n<source><g=m><o=b><age=50><status=1><abo...
# 3     \n\n\n<source><g=m><o=b><age=50><status=1><abo...
# 4     \n\n\n<source><g=m><o=b><age=50><status=1><abo...
# ...                                                 ...
# 1349  load failed: File read failed: 'utf-8' codec c...
# 1350  load failed: File read failed: 'utf-8' codec c...
# 1351  \n\n\n<source><g=m><o=a><age=54><status=2><abo...
# 1352  \n\n\n<source><g=m><o=a><age=48><status=2><abo...
# 1353  <source><g=m><o=a><age=31><status=2><abode=nv>...
#
#      ldac:linguisticGenre_sameAs author_description
# 0                           None               None
# 1                           None               None
# 2                           None               None
# 3                           None               None
# 4                           None               None
# ...                          ...                ...
# 1349                        None               None
# 1350                        None               None
# 1351                        None               None
# 1352                        None               None
# 1353                                           None
#
# [1354 rows x 55 columns]

# %% [markdown]
# ## Getting People

# %%
text_data.columns
# Out:
# Index(['name', 'author_@type', 'author_name', 'author_birthDate',
#        'author_local:birthDateEstimateStart',
#        'author_local:birthDateEstimateEnd', 'author_birthPlace',
#        'author_gender', 'author_local:arrivalDate',
#        'author_local:arrivalDateEstimateStart',
#        'author_local:arrivalDateEstimateEnd',
#        'author_local:yearsLivedInAustralia', 'author_ldac:age',
#        'author_local:socialClass', 'author_prov:specializationOf',
#        'description', 'dateCreated', 'register_name', 'register_description',
#        'register_@type', 'register_inDefinedTermSet', 'textType_name',
#        'textType_description', 'textType_@type', 'textType_inDefinedTermSet',
#        'temporal', 'locationCreated', 'ldac:linguisticGenre_@type',
#        'ldac:linguisticGenre_name', 'ldac:linguisticGenre_description',
#        'ldac:linguisticGenre_inDefinedTermSet', 'datePublished', 'citation',
#        'recipient_name', 'recipient_socialClass', 'recipient_homeLocation',
#        'recipient_@type', 'recipient_gender', 'ldac:communicationMode_@type',
#        'ldac:communicationMode_name', 'ldac:communicationMode_description',
#        'ldac:communicationMode_inDefinedTermSet', 'inLanguage',
#        'ldac:indexableText_name', 'ldac:indexableText_@type',
#        'ldac:indexableText_materialType',
#        'ldac:indexableText_ldac:annotationOf', 'ldac:indexableText_inLanguage',
#        'ldac:indexableText_encodingFormat',
#        'ldac:indexableText_encodingFormat_1',
#        'ldac:indexableText_ldac:communicationMode',
#        'ldac:indexableText_contentSize', 'ldac:mainText',
#        'ldac:linguisticGenre_sameAs', 'author_description'],
#       dtype='object')

# %% [markdown]
# ## Getting the organizations

# %%
ldac_tb.corpus_specific_tables_list()
# Out:
# "Corpus-specific tables: ['Dataset', 'DefinedTerm', 'File']. Use corpus_specific_tables(table_name) to load the data."
