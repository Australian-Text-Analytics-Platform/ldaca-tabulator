# %% [markdown]
# # Example Code

# %% [markdown]
# ## Importing packages

# %%
from src.tabulator import LDaCATabulator

# %% [markdown]
# ## Downloading corpus and decompress the folder

# %%
zip_url = "https://data.ldaca.edu.au/api/object/arcp%3A%2F%2Fname%2Chdl10.26181~23089559.zip"

ldac_tb = LDaCATabulator(zip_url)
# Out:
# 100%|██████████| 57/57 [00:00<00:00, 52671.37it/s]

# %% [markdown]
# ## Getting metadata and text data

# %%
text_data = ldac_tb.get_text()
text_data
# Out:
# 100%|██████████| 12/12 [00:00<00:00, 2572.40it/s]
#    inLanguage datePublished  \
# 0     English          2002
# 1     English          2002
# 2     English          2002
# 3     English          2002
# 4     English          2002
# 5     English          2002
# 6     English          2002
# 7     English          2002
# 8     English          2002
# 9     English          2002
# 10    English          2002
# 11    English          2002
#
#                                           description dateCreated  \
# 0   Participants were informed that the researcher...  2001-06-09
# 1   Participants were informed that the researcher...  2001-06-09
# 2   Participants were informed that the researcher...  2001-05-30
# 3   Participants were informed that the researcher...  2001-05-30
# 4   Participants were informed that the researcher...  2001-06-17
# 5   Participants were informed that the researcher...  2001-06-17
# 6   Participants were informed that the researcher...  2001-06-17
# ...

# %% [markdown]
# ## Getting People

# %%
people_df = ldac_tb.get_people()
people_df
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 5683.34it/s]
#            name
# 0  Kerry Mullan

# %% [markdown]
# ## Getting the organizations

# %%
org_df = ldac_tb.get_organization()
org_df
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 2174.34it/s]
#                   name
# 0  La Trobe University
