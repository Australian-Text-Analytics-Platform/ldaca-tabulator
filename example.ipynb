# %%
from src.loader import expand_for_entity_types

# %% [markdown]
# # Example code

# %%
# COOEE corpus url
zip_url = "https://data.ldaca.edu.au/api/object/arcp%3A%2F%2Fname%2Chdl10.26180~23961609.zip"

# Run the function
prop_types, df = expand_for_entity_types(
    zip_url=zip_url,
    verbose=True  
)
# Out:
# 100%|██████████| 8078/8078 [00:07<00:00, 1013.82it/s]
# 100%|██████████| 1322/1322 [00:11<00:00, 116.47it/s]
# 100%|██████████| 2439/2439 [00:21<00:00, 115.01it/s]
# 100%|██████████| 13/13 [00:00<00:00, 106.36it/s]
# 100%|██████████| 1/1 [00:00<00:00, 113.22it/s]
# Dataset.hasPart > 10 relations
# Dataset.pcdm:hasMember > 10 relations
# 100%|██████████| 2/2 [00:01<00:00,  1.01it/s]
# 100%|██████████| 1/1 [00:00<00:00, 111.33it/s]
# 100%|██████████| 2713/2713 [00:23<00:00, 115.73it/s]
# 100%|██████████| 1/1 [00:00<00:00, 115.54it/s]
# 100%|██████████| 3/3 [00:00<00:00, 113.86it/s]
# 100%|██████████| 3/3 [00:00<00:00, 115.64it/s]
# 100%|██████████| 28/28 [00:00<00:00, 115.75it/s]
# 100%|██████████| 8/8 [00:00<00:00, 114.54it/s]
# 100%|██████████| 3/3 [00:00<00:00, 113.62it/s]
# RepositoryCollection.hasPart > 10 relations
# RepositoryCollection.pcdm:hasMember > 10 relations
# 100%|██████████| 1/1 [00:01<00:00,  1.79s/it]
# 100%|██████████| 32/32 [00:00<00:00, 114.35it/s]
# 100%|██████████| 1/1 [00:00<00:00, 115.58it/s]
# 100%|██████████| 1354/1354 [00:11<00:00, 115.74it/s]
# 100%|██████████| 156/156 [00:01<00:00, 114.55it/s]
# 100%|██████████| 1/1 [00:00<00:00, 110.87it/s]
# 100%|██████████| 1/1 [00:00<00:00, 114.03it/s]
# Expanding 11 properties: ['author', 'register', 'textType', 'locationCreated', 'ldac:linguisticGenre', 'citation', 'recipient', 'ldac:communicationMode', 'ldac:indexableText', 'ldac:mainText', 'hasPart']
# 100%|██████████| 1354/1354 [02:18<00:00,  9.78it/s]

# %%
df
# Out:
#      dateCreated                                 ldac:indexableText  \
# 0           1788  Dear Sir,\nI have the pleasure of sending you ...
# 1           1788  \n\n\nMy Lord,\nAs I was unwilling to trouble ...
# 2           1788  \n\n\nThe Supply, sailing very badly, had not ...
# 3           1788  \n\n\nYour Lordship will permit me to observe ...
# 4           1788   every day proves the necessity of proper pers...
# ...          ...                                                ...
# 1349        1897  \n\n\nSir GEORGE TURNER:  \nI am pleased indee...
# 1350        1898  \n\n\nMr. LYNE. -  \nI have not seen it. But I...
# 1351        1898  \n\n\nSir JOHN DOWNER (South Australia). -  \n...
# 1352        1898  \n\n\nMr. KINGSTON. -  \nI think we must recog...
# 1353        1895  Once a jolly swagman camped by a Billabong\nUn...
#
#                                     description locationCreated  \
# 0                Text 1-001 1788 Philip, Arthur            None
# 1                Text 1-002 1788 Philip, Arthur            None
# 2                Text 1-003 1788 Philip, Arthur            None
# 3                Text 1-004 1788 Philip, Arthur            None
# 4                Text 1-005 1788 Philip, Arthur            None
# ...                                         ...             ...
# 1349             Text 4-421 1897 Turner, George            None
# 1350         Text 4-422 1898 Lyne, William John            None
# 1351       Text 4-423 1898 Downer, John William            None
# 1352  Text 4-424 1898 Kingston, Charles Cameron            None
# 1353    Text 4-425 1895 Paterson, Andrew Barton            None
#
#      ldac:communicationMode identifier   temporal recipient textType  \
# 0                      None      1-001  1788/1825      None     None
# 1                      None      1-002  1788/1825      None     None
# 2                      None      1-003  1788/1825      None     None
# 3                      None      1-004  1788/1825      None     None
# 4                      None      1-005  1788/1825      None     None
# ...                     ...        ...        ...       ...      ...
# 1349                   None      4-421  1876/1900      None     None
# 1350                   None      4-422  1876/1900      None     None
# 1351                   None      4-423  1876/1900      None     None
# 1352                   None      4-424  1876/1900      None     None
# 1353                   None      4-425  1876/1900      None     None
#
#      datePublished  ... ldac:mainText_materialType  \
# 0             1998  ...            DerivedMaterial
# 1             1998  ...            DerivedMaterial
# 2             1977  ...            DerivedMaterial
# 3             1977  ...            DerivedMaterial
# 4             1977  ...            DerivedMaterial
# ...            ...  ...                        ...
# 1349          1897  ...            DerivedMaterial
# 1350          1898  ...            DerivedMaterial
# 1351          1898  ...            DerivedMaterial
# 1352          1898  ...            DerivedMaterial
# 1353          1895  ...            DerivedMaterial
#
#                      ldac:communicationMode_description hasPart_inLanguage  \
# 0     The resource contains data for which the mediu...            English
# 1     The resource contains data for which the mediu...            English
# 2     The resource contains data for which the mediu...            English
# 3     The resource contains data for which the mediu...            English
# 4     The resource contains data for which the mediu...            English
# ...                                                 ...                ...
# 1349  The resource contains data for which the mediu...            English
# 1350  The resource contains data for which the mediu...            English
# 1351  The resource contains data for which the mediu...            English
# 1352  The resource contains data for which the mediu...            English
# 1353  The resource contains data for which the mediu...            English
#
#      hasPart_ldac:communicationMode  \
# 0                   WrittenLanguage
# 1                   WrittenLanguage
# 2                   WrittenLanguage
# 3                   WrittenLanguage
# 4                   WrittenLanguage
# ...                             ...
# 1349                 SpokenLanguage
# 1350                 SpokenLanguage
# 1351                 SpokenLanguage
# 1352                 SpokenLanguage
# 1353                WrittenLanguage
#
#                                           hasPart_name  \
# 0                Text 1-001 1788 Philip, Arthur - text
# 1                Text 1-002 1788 Philip, Arthur - text
# 2                Text 1-003 1788 Philip, Arthur - text
# 3                Text 1-004 1788 Philip, Arthur - text
# 4                Text 1-005 1788 Philip, Arthur - text
# ...                                                ...
# 1349             Text 4-421 1897 Turner, George - text
# 1350         Text 4-422 1898 Lyne, William John - text
# 1351       Text 4-423 1898 Downer, John William - text
# 1352  Text 4-424 1898 Kingston, Charles Cameron - text
# 1353    Text 4-425 1895 Paterson, Andrew Barton - text
#
#                        ldac:linguisticGenre_description  \
# 0     Discourse whose primary purpose is to inform t...
# 1     Discourse whose primary purpose is to inform t...
# 2     Discourse whose primary purpose is to inform t...
# 3     Discourse whose primary purpose is to inform t...
# 4     Discourse whose primary purpose is to inform t...
# ...                                                 ...
# 1349  Discourse whose primary purpose is to inform t...
# 1350  Discourse whose primary purpose is to inform t...
# 1351  Discourse whose primary purpose is to inform t...
# 1352  Discourse whose primary purpose is to inform t...
# 1353  The resource is a ritually or conventionally s...
#
#      ldac:mainText_ldac:communicationMode ldac:linguisticGenre_name  \
# 0                         WrittenLanguage             Informational
# 1                         WrittenLanguage             Informational
# 2                         WrittenLanguage             Informational
# 3                         WrittenLanguage             Informational
# 4                         WrittenLanguage             Informational
# ...                                   ...                       ...
# 1349                       SpokenLanguage             Informational
# 1350                       SpokenLanguage             Informational
# 1351                       SpokenLanguage             Informational
# 1352                       SpokenLanguage             Informational
# 1353                      WrittenLanguage                 Formulaic
#
#        recipient_name hasPart_materialType
# 0     1-001 Recipient      DerivedMaterial
# 1     1-002 Recipient      DerivedMaterial
# 2     1-003 Recipient      DerivedMaterial
# 3     1-004 Recipient      DerivedMaterial
# 4     1-005 Recipient      DerivedMaterial
# ...               ...                  ...
# 1349             None      DerivedMaterial
# 1350             None      DerivedMaterial
# 1351             None      DerivedMaterial
# 1352             None      DerivedMaterial
# 1353             None      DerivedMaterial
#
# [1354 rows x 61 columns]
