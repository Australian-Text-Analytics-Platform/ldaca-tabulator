# %% [markdown]
# # Example Code

# %%
from src.tabulator import LDaCATabulator

# %%
zip_url = "https://data.ldaca.edu.au/api/object/arcp%3A%2F%2Fname%2Chdl10.25949~24769173.v1.zip"

ldac_tb = LDaCATabulator(zip_url)

df = ldac_tb.get_text()
# Out:
# 100%|██████████| 6423/6423 [00:04<00:00, 1539.22it/s]
# RepositoryObject.hasPart > 10 relations
# RepositoryObject.ldac:speaker > 10 relations
# RepositoryObject.hasPart > 10 relations
# 100%|██████████| 558/558 [00:12<00:00, 45.65it/s]

# %%
df = ldac_tb.get_people()
# Out:
# 100%|██████████| 753/753 [00:03<00:00, 197.71it/s]

# %%
df
# Out:
#                                              entity_id        name education  \
# 0                   http://nla.gov.au/nla.party-556106  Pam Peters      None
# 1    arcp://name,hdl10.25949~24769173.v1/speaker/S1...        None      Tafe
# 2    arcp://name,hdl10.25949~24769173.v1/speaker/S1...        None        MA
# 3    arcp://name,hdl10.25949~24769173.v1/speaker/S1...        None      None
# 4    arcp://name,hdl10.25949~24769173.v1/speaker/S1...        None      BEng
# ..                                                 ...         ...       ...
# 748  arcp://name,hdl10.25949~24769173.v1/speaker/S2...        None      None
# 749  arcp://name,hdl10.25949~24769173.v1/speaker/S2...        None      None
# 750  arcp://name,hdl10.25949~24769173.v1/speaker/S2...        None      None
# 751  arcp://name,hdl10.25949~24769173.v1/speaker/S2...        None       HSC
# 752  arcp://name,hdl10.25949~24769173.v1/speaker/S2...        None      None
#
# ...
