# %% [markdown]
# # Example Code

# %%
from src.tabulator import LDaCATabulator

# %%
zip_url = "https://data.ldaca.edu.au/api/object/arcp%3A%2F%2Fname%2Chdl10.26180~23961609.zip"

ldac_tb = LDaCATabulator(zip_url)

df = ldac_tb.get_text()
# Out:
# 100%|██████████| 57/57 [00:00<00:00, 41127.70it/s]
# 100%|██████████| 12/12 [00:00<00:00, 1902.61it/s]

# %%
df.columns
# Out:
# Index(['inLanguage', 'datePublished', 'description', 'dateCreated',
#        'ldac:communicationMode_name',
#        'ldac:communicationMode_inDefinedTermSet', 'name', 'ldac:annotationOf',
#        'ldac:annotationOf_id', 'ldac:annotationType', 'ldac:mainText',
#        'ldac:indexableText_name', 'ldac:indexableText_encodingFormat',
#        'ldac:indexableText_encodingFormat_1',
#        'ldac:indexableText_ldac:communicationMode',
#        'ldac:indexableText_ldac:linguisticGenre',
#        'ldac:indexableText_ldac:annotationType', 'ldac:indexableText_size',
#        'ldac:indexableText_extent', 'ldac:indexableText_contentSize',
#        'ldac:speaker', 'ldac:hasAnnotation'],
#       dtype='object')
