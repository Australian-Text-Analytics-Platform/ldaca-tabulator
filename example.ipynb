# %% [markdown]
# # Example Code

# %%
from src.tabulator import LDaCATabulator

# %%
# COOEE corpus url
zip_url = "https://data.ldaca.edu.au/api/object/arcp%3A%2F%2Fname%2Chdl10.25949~24769173.v1.zip"

ldac_tb = LDaCATabulator(zip_url)

ldac_tb.get_text()
# Out:
# 100%|██████████| 6423/6423 [00:04<00:00, 1584.41it/s]
# 100%|██████████| 1/1 [00:00<00:00, 185.11it/s]
# Dataset.hasPart > 10 relations
# Dataset.pcdm:hasMember > 10 relations
# Dataset.hasPart > 10 relations
# Dataset.pcdm:hasMember > 10 relations
# Dataset.hasPart > 10 relations
# Dataset.pcdm:hasMember > 10 relations
# Dataset.hasPart > 10 relations
# Dataset.pcdm:hasMember > 10 relations
# Dataset.hasPart > 10 relations
# Dataset.pcdm:hasMember > 10 relations
# Dataset.hasPart > 10 relations
# Dataset.pcdm:hasMember > 10 relations
# Dataset.hasPart > 10 relations
# Dataset.pcdm:hasMember > 10 relations
# Dataset.hasPart > 10 relations
# Dataset.pcdm:hasMember > 10 relations
# Dataset.hasPart > 10 relations
# Dataset.pcdm:hasMember > 10 relations
# Dataset.hasPart > 10 relations
# Dataset.pcdm:hasMember > 10 relations
# Dataset.hasPart > 10 relations
# Dataset.pcdm:hasMember > 10 relations
# Dataset.pcdm:hasMember > 10 relations
# 100%|██████████| 13/13 [00:00<00:00, 24.26it/s]
# RepositoryCollection.hasPart > 10 relations
# RepositoryCollection.pcdm:hasMember > 10 relations
# RepositoryCollection.hasPart > 10 relations
# RepositoryCollection.pcdm:hasMember > 10 relations
# RepositoryCollection.hasPart > 10 relations
# RepositoryCollection.pcdm:hasMember > 10 relations
# RepositoryCollection.hasPart > 10 relations
# RepositoryCollection.pcdm:hasMember > 10 relations
# RepositoryCollection.hasPart > 10 relations
# RepositoryCollection.pcdm:hasMember > 10 relations
# RepositoryCollection.hasPart > 10 relations
# RepositoryCollection.pcdm:hasMember > 10 relations
# RepositoryCollection.hasPart > 10 relations
# RepositoryCollection.pcdm:hasMember > 10 relations
# RepositoryCollection.hasPart > 10 relations
# RepositoryCollection.pcdm:hasMember > 10 relations
# RepositoryCollection.hasPart > 10 relations
# RepositoryCollection.pcdm:hasMember > 10 relations
# RepositoryCollection.hasPart > 10 relations
# RepositoryCollection.pcdm:hasMember > 10 relations
# RepositoryCollection.hasPart > 10 relations
# RepositoryCollection.pcdm:hasMember > 10 relations
# RepositoryCollection.pcdm:hasMember > 10 relations
# 100%|██████████| 13/13 [00:00<00:00, 24.93it/s]
# 100%|██████████| 1/1 [00:00<00:00, 186.88it/s]
# 100%|██████████| 753/753 [00:03<00:00, 198.99it/s]
# 100%|██████████| 1/1 [00:00<00:00, 193.15it/s]
# 100%|██████████| 1/1 [00:00<00:00, 190.43it/s]
# RepositoryObject.hasPart > 10 relations
# RepositoryObject.ldac:speaker > 10 relations
# RepositoryObject.hasPart > 10 relations
# 100%|██████████| 558/558 [00:05<00:00, 104.04it/s]
# 100%|██████████| 5079/5079 [00:26<00:00, 191.86it/s]
# 100%|██████████| 12/12 [00:00<00:00, 156.29it/s]
# 100%|██████████| 1/1 [00:00<00:00, 179.24it/s]
# 100%|██████████| 1/1 [00:00<00:00, 182.74it/s]
# 100%|██████████| 1/1 [00:00<00:00, 157.75it/s]
# Expanding 7 properties: ['hasPart', 'ldac:speaker', 'license', 'ldac:communicationMode', 'ldac:linguisticGenre', 'ldac:indexableText', 'ldac:mainText']
# RepositoryObject.hasPart > 10 relations
# RepositoryObject.ldac:speaker > 10 relations
# RepositoryObject.hasPart > 10 relations
#   0%|          | 0/558 [00:00<?, ?it/s]
# RepositoryObject: too many values for 'hasPart_encodingFormat', ignoring it.
# RepositoryObject.hasPart > 10 relations
# RepositoryObject.ldac:speaker > 10 relations
# RepositoryObject.hasPart > 10 relations
#   7%|▋         | 38/558 [00:03<00:48, 10.73it/s]
# RepositoryObject: too many values for 'hasPart_name', ignoring it.
# RepositoryObject.hasPart > 10 relations
# RepositoryObject.ldac:speaker > 10 relations
# RepositoryObject.hasPart > 10 relations
#   7%|▋         | 38/558 [00:03<00:48, 10.83it/s]
# RepositoryObject: too many values for 'hasPart_@type', ignoring it.
# RepositoryObject.hasPart > 10 relations
# RepositoryObject.ldac:speaker > 10 relations
# RepositoryObject.hasPart > 10 relations
#   7%|▋         | 38/558 [00:03<00:48, 10.78it/s]
# RepositoryObject: too many values for 'hasPart_license', ignoring it.
# RepositoryObject.hasPart > 10 relations
# RepositoryObject.ldac:speaker > 10 relations
# RepositoryObject.hasPart > 10 relations
#   7%|▋         | 38/558 [00:03<00:48, 10.73it/s]
# RepositoryObject: too many values for 'hasPart_contentSize', ignoring it.
# RepositoryObject.hasPart > 10 relations
# RepositoryObject.ldac:speaker > 10 relations
# RepositoryObject.hasPart > 10 relations
# 100%|██████████| 558/558 [00:45<00:00, 12.26it/s]
#                                     ldac:indexableText  \
# 0    So you gonna be speaking yourself this afterno...
# 1    Somewhere I was recently I can't remember wher...
# 2    Now what I wanted to see these for forenameB u...
# 3    Mum, we saw a flower today in that bloke next ...
# 4    Yeah I think so \nMmm \nWhere's the little boy...
# ..                                                 ...
# 553  8 Set down this: a conversation had already la...
# 554  Bondi At twenty-six, Leigh (who is Cass's cous...
# 555  YIORGOS THE APEFACE WOKE UP EVERY MORNING WITH...
# 556  Sixteen Q UITE SUDDENLY, AND WITHOUT A CHANGE ...
# 557  A Change in the Lighting \nbullet VIII bullet ...
#
#                                            description ldac:communicationMode  \
# 0                            Friendly debate in Domain                   None
# 1      Dinner party:  plants, buildings Gulf War, USSR                   None
# 2           2M talking re holidays in Port Douglas Qld                   None
# 3          Family talking about food, wine and romance                   None
# 4    Family discussion re restaurants, rides at fun...                   None
# ..                                                 ...                    ...
# 553                                               None                   None
# 554                                               None                   None
# 555                                               None                   None
# 556                                               None                   None
# 557                                               None                   None
#
#     datePublished ldac:mainText ldac:linguisticGenre  \
# 0      1992-06-14          None                 None
# 1      1991-12-01          None                 None
# 2      1917-05-93          None                 None
# 3      1992-10-14          None                 None
# 4      1992-09-19          None                 None
# ..            ...           ...                  ...
# 553          None          None                 None
# 554          None          None                 None
# 555          None          None                 None
# 556          None          None                 None
# 557          None          None                 None
#
#                                                   name inLanguage  \
# 0    S1A-001 : Conversation - Friendly debate in Do...    English
# 1    S1A-002 : Conversation - Dinner party:  plants...    English
# 2    S1A-003 : Conversation - 2M talking re holiday...    English
# 3    S1A-004 : Conversation - Family talking about ...    English
# 4    S1A-005 : Conversation - Family discussion re ...    English
# ..                                                 ...        ...
# 553            W2F-016 : The Last Magician - Chapter 8    English
# 554                          W2F-017 : Isobars - Bondi    English
# 555        W2F-018 : The Mule's Foal - The Mule's Foal    English
# 556                  W2F-019 : The Riders - Chapter 16    English
# 557     W2F-020 : A Change In The Lighting - Chapter 8    English
#
#     ldac:mainText_name ldac:linguisticGenre_name  \
# 0          S1A-001.TXT                  Dialogue
# 1          S1A-002.TXT                  Dialogue
# 2          S1A-003.TXT                  Dialogue
# 3          S1A-004.TXT                  Dialogue
# 4          S1A-005.TXT                  Dialogue
# ..                 ...                       ...
# 553        W2F-016.TXT                 Narrative
# 554        W2F-017.TXT                 Narrative
# 555        W2F-018.TXT                 Narrative
# 556        W2F-019.TXT                 Narrative
# 557        W2F-020.TXT                 Narrative
#
#                       ldac:linguisticGenre_description ldac:speaker_gender  \
# 0    An interactive discourse with two or more part...                male
# 1    An interactive discourse with two or more part...                male
# 2    An interactive discourse with two or more part...                male
# 3    An interactive discourse with two or more part...                male
# 4    An interactive discourse with two or more part...                male
# ..                                                 ...                 ...
# 553  A discourse, monologic or co-constructed, whic...                None
# 554  A discourse, monologic or co-constructed, whic...                None
# 555  A discourse, monologic or co-constructed, whic...                None
# 556  A discourse, monologic or co-constructed, whic...                None
# 557  A discourse, monologic or co-constructed, whic...                None
#
#                                    hasPart_description  \
# 0    This file is a N-Triples file containing metad...
# 1    This file is a N-Triples file containing metad...
# 2    This file is a N-Triples file containing metad...
# 3    This file is a N-Triples file containing metad...
# 4    This file is a N-Triples file containing metad...
# ..                                                 ...
# 553  This file is a N-Triples file containing metad...
# 554  This file is a N-Triples file containing metad...
# 555  This file is a N-Triples file containing metad...
# 556  This file is a N-Triples file containing metad...
# 557  This file is a N-Triples file containing metad...
#
#     hasPart_ldac:communicationMode ldac:mainText_contentSize  \
# 0                   SpokenLanguage                     14890
# 1                   SpokenLanguage                     15126
# 2                   SpokenLanguage                     13512
# 3                   SpokenLanguage                     16362
# 4                   SpokenLanguage                     18992
# ..                             ...                       ...
# 553                WrittenLanguage                     12309
# 554                WrittenLanguage                     13193
# 555                WrittenLanguage                     11617
# 556                WrittenLanguage                     12493
# 557                WrittenLanguage                     12988
#
#                              ldac:mainText_description  \
# 0    This file is a TXT file containing marked-up t...
# 1    This file is a TXT file containing marked-up t...
# 2    This file is a TXT file containing marked-up t...
# 3    This file is a TXT file containing marked-up t...
# 4    This file is a TXT file containing marked-up t...
# ..                                                 ...
# 553  This file is a TXT file containing marked-up t...
# 554  This file is a TXT file containing marked-up t...
# 555  This file is a TXT file containing marked-up t...
# 556  This file is a TXT file containing marked-up t...
# 557  This file is a TXT file containing marked-up t...
#
#                     ldac:communicationMode_description  \
# 0    The resource contains data for which the mediu...
# 1    The resource contains data for which the mediu...
# 2    The resource contains data for which the mediu...
# 3    The resource contains data for which the mediu...
# 4    The resource contains data for which the mediu...
# ..                                                 ...
# 553  The resource contains data for which the mediu...
# 554  The resource contains data for which the mediu...
# 555  The resource contains data for which the mediu...
# 556  The resource contains data for which the mediu...
# 557  The resource contains data for which the mediu...
#
#     ldac:communicationMode_name
# 0                SpokenLanguage
# 1                SpokenLanguage
# 2                SpokenLanguage
# 3                SpokenLanguage
# 4                SpokenLanguage
# ..                          ...
# 553             WrittenLanguage
# 554             WrittenLanguage
# 555             WrittenLanguage
# 556             WrittenLanguage
# 557             WrittenLanguage
#
# [558 rows x 18 columns]
