# %% [markdown]
# # Example Code

# %%
from src.tabulator import LDaCATabulator

# %%
# COOEE corpus url
zip_url = "https://data.ldaca.edu.au/api/object/arcp%3A%2F%2Fname%2Chdl10.26180~23961609.zip"

ldac_tb = LDaCATabulator(zip_url)

#ldac_tb.get_text(include_metadata=False)
# Out:
# 100%|██████████| 8078/8078 [00:08<00:00, 1002.44it/s]

# %%
ldac_tb.get_people()
# Out:
# 100%|██████████| 2439/2439 [00:22<00:00, 109.24it/s]
#      description local:arrivalDateEstimateStart homeLocation       birthPlace  \
# 0           None                           None         None             None
# 1           None                           1788         None    Great Britain
# 2           None                           1788         None    Great Britain
# 3           None                           None      England             None
# 4           None                           1788         None    Great Britain
# ...          ...                            ...          ...              ...
# 2434        None                           1844         None  South Australia
# 2435        None                           1844         None  South Australia
# 2436        None                           1850         None  South Australia
# 2437        None                           1850         None  South Australia
# 2438        None                           1864         None  New South Wales
#
#      local:yearsLivedInAustralia   local:socialClass         socialClass  \
# 0                           None                None                None
# 1                              0         Upper Class                None
# 2                              0                None                None
# 3                           None                None  Upper Middle Class
# 4                              0         Upper Class                None
# ...                          ...                 ...                 ...
# 2434                          nv  Upper Middle Class                None
# 2435                          nv                None                None
# 2436                          nv  Upper Middle Class                None
# 2437                          nv                None                None
# 2438                          nv  Upper Middle Class                None
#
#                                                    name local:arrivalDate  \
# 0                                   Clemens W. A. Fritz              None
# 1              Philip, Arthur - status 1788 text #1-001              1788
# 2                                        Philip, Arthur              1788
# 3                                       1-001 Recipient              None
# 4              Philip, Arthur - status 1788 text #1-002              1788
# ...                                                 ...               ...
# 2434     Downer, John William - status 1898 text #4-423              None
# 2435                               Downer, John William              None
# 2436  Kingston, Charles Cameron - status 1898 text #...              None
# 2437                          Kingston, Charles Cameron              None
# 2438  Paterson, Andrew Barton - status 1895 text #4-425              None
#
#      local:birthDateEstimateStart      prov:specializationOf gender  \
# 0                            None                       None   None
# 1                            1738             Philip, Arthur      m
# 2                            1738                       None      m
# 3                            None                       None      m
# 4                            1738             Philip, Arthur      m
# ...                           ...                        ...    ...
# 2434                         1844       Downer, John William      m
# 2435                         1844                       None      m
# 2436                         1850  Kingston, Charles Cameron      m
# 2437                         1850                       None      m
# 2438                         1864    Paterson, Andrew Barton      m
#
#      local:birthDateEstimateEnd birthDate local:arrivalDateEstimateEnd  \
# 0                          None      None                         None
# 1                          1738      1738                         1788
# 2                          1738      1738                         1788
# 3                          None      None                         None
# 4                          1738      1738                         1788
# ...                         ...       ...                          ...
# 2434                       1844      1844                         1844
# 2435                       1844      1844                         1844
# 2436                       1850      1850                         1850
# 2437                       1850      1850                         1850
# 2438                       1864      1864                         1864
#
#      ldac:age
# 0        None
# 1          50
# 2        None
# 3        None
# 4          50
# ...       ...
# 2434       54
# 2435     None
# 2436       48
# 2437     None
# 2438       31
#
# [2439 rows x 16 columns]

# %%
import json
with open("./config/config.json") as f:
            config = json.load(f)

# %%
config['tables']['Person'].get('properties', [])
# Out:
# ['description',
#  'local:arrivalDateEstimateStart',
#  'homeLocation',
#  'birthPlace',
#  'local:yearsLivedInAustralia',
#  'local:socialClass',
#  'socialClass',
#  'name',
#  'local:arrivalDate',
#  'local:birthDateEstimateStart',
#  'prov:specializationOf',
#  'gender',
#  'local:birthDateEstimateEnd',
#  'birthDate',
#  'local:arrivalDateEstimateEnd',
#  'ldac:age']
