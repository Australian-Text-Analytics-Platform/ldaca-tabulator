# %% [markdown]
# # Example Code

# %% [markdown]
# ## Importing packages

# %%
from ldacatabulator.tabulator import LDaCATabulator

# %% [markdown]
# ## Downloading corpus and decompress the folder

# %%
zip_url = "https://data.ldaca.edu.au/api/object/arcp%3A%2F%2Fname%2Chdl10.26180~23961609.zip"

ldac_tb = LDaCATabulator(zip_url)
# Out:
# 100%|██████████| 8078/8078 [00:07<00:00, 1026.13it/s]

# %% [markdown]
# ## Getting metadata and text data

# %%
text_data = ldac_tb.get_text()
text_data
# Out:
# 100%|██████████| 1354/1354 [01:28<00:00, 15.24it/s]
#                                         entity_id  \
# 0     arcp://name,hdl10.26180~23961609/item/1-001
# 1     arcp://name,hdl10.26180~23961609/item/1-002
# 2     arcp://name,hdl10.26180~23961609/item/1-003
# 3     arcp://name,hdl10.26180~23961609/item/1-004
# 4     arcp://name,hdl10.26180~23961609/item/1-005
# ...                                           ...
# 1349  arcp://name,hdl10.26180~23961609/item/4-421
# 1350  arcp://name,hdl10.26180~23961609/item/4-422
# 1351  arcp://name,hdl10.26180~23961609/item/4-423
# 1352  arcp://name,hdl10.26180~23961609/item/4-424
# 1353  arcp://name,hdl10.26180~23961609/item/4-425
#
#                                            name author_@type  \
# 0                Text 1-001 1788 Philip, Arthur       Person
# 1                Text 1-002 1788 Philip, Arthur       Person
# 2                Text 1-003 1788 Philip, Arthur       Person
# 3                Text 1-004 1788 Philip, Arthur       Person
# 4                Text 1-005 1788 Philip, Arthur       Person
# ...                                         ...          ...
# 1349             Text 4-421 1897 Turner, George       Person
# 1350         Text 4-422 1898 Lyne, William John       Person
# 1351       Text 4-423 1898 Downer, John William       Person
# 1352  Text 4-424 1898 Kingston, Charles Cameron       Person
# 1353    Text 4-425 1895 Paterson, Andrew Barton       Person
#
#                                             author_name author_birthDate  \
# 0              Philip, Arthur - status 1788 text #1-001             1738
# 1              Philip, Arthur - status 1788 text #1-002             1738
# 2              Philip, Arthur - status 1788 text #1-003             1738
# 3              Philip, Arthur - status 1788 text #1-004             1738
# 4              Philip, Arthur - status 1788 text #1-005             1738
# ...                                                 ...              ...
# 1349           Turner, George - status 1897 text #4-421             1851
# 1350       Lyne, William John - status 1898 text #4-422             1844
# 1351     Downer, John William - status 1898 text #4-423             1844
# 1352  Kingston, Charles Cameron - status 1898 text #...             1850
# 1353  Paterson, Andrew Barton - status 1895 text #4-425             1864
#
#      author_local:birthDateEstimateStart author_local:birthDateEstimateEnd  \
# 0                                   1738                              1738
# 1                                   1738                              1738
# 2                                   1738                              1738
# 3                                   1738                              1738
# 4                                   1738                              1738
# ...                                  ...                               ...
# 1349                                1851                              1851
# 1350                                1844                              1844
# 1351                                1844                              1844
# 1352                                1850                              1850
# 1353                                1864                              1864
#
#       author_birthPlace author_birthPlace_id author_gender  ...  \
# 0         Great Britain            #place_GB             m  ...
# 1         Great Britain            #place_GB             m  ...
# 2         Great Britain            #place_GB             m  ...
# 3         Great Britain            #place_GB             m  ...
# 4         Great Britain            #place_GB             m  ...
# ...                 ...                  ...           ...  ...
# 1349           Victoria         #place_A-VIC             m  ...
# 1350  Van Diemen's Land         #place_A-VDL             m  ...
# 1351    South Australia          #place_A-SA             m  ...
# 1352    South Australia          #place_A-SA             m  ...
# 1353    New South Wales         #place_A-NSW             m  ...
#
#      ldac:indexableText_encodingFormat ldac:indexableText_encodingFormat_1  \
# 0                           text/plain
# 1                           text/plain
# 2                           text/plain
# 3                           text/plain
# 4                           text/plain
# ...                                ...                                 ...
# 1349                        text/plain
# 1350                        text/plain
# 1351                        text/plain
# 1352                        text/plain
# 1353                        text/plain
#
#                    ldac:indexableText_encodingFormat_id  \
# 0     https://www.nationalarchives.gov.uk/PRONOM/x-f...
# 1     https://www.nationalarchives.gov.uk/PRONOM/x-f...
# 2     https://www.nationalarchives.gov.uk/PRONOM/x-f...
# 3     https://www.nationalarchives.gov.uk/PRONOM/x-f...
# 4     https://www.nationalarchives.gov.uk/PRONOM/x-f...
# ...                                                 ...
# 1349  https://www.nationalarchives.gov.uk/PRONOM/x-f...
# 1350  https://www.nationalarchives.gov.uk/PRONOM/x-f...
# 1351  https://www.nationalarchives.gov.uk/PRONOM/x-f...
# 1352  https://www.nationalarchives.gov.uk/PRONOM/x-f...
# 1353  https://www.nationalarchives.gov.uk/PRONOM/x-f...
#
#      ldac:indexableText_ldac:communicationMode  \
# 0                              WrittenLanguage
# 1                              WrittenLanguage
# 2                              WrittenLanguage
# 3                              WrittenLanguage
# 4                              WrittenLanguage
# ...                                        ...
# 1349                            SpokenLanguage
# 1350                            SpokenLanguage
# 1351                            SpokenLanguage
# 1352                            SpokenLanguage
# 1353                           WrittenLanguage
#
#      ldac:indexableText_ldac:communicationMode_id  \
# 0     https://w3id.org/ldac/terms#WrittenLanguage
# 1     https://w3id.org/ldac/terms#WrittenLanguage
# 2     https://w3id.org/ldac/terms#WrittenLanguage
# 3     https://w3id.org/ldac/terms#WrittenLanguage
# 4     https://w3id.org/ldac/terms#WrittenLanguage
# ...                                           ...
# 1349   https://w3id.org/ldac/terms#SpokenLanguage
# 1350   https://w3id.org/ldac/terms#SpokenLanguage
# 1351   https://w3id.org/ldac/terms#SpokenLanguage
# 1352   https://w3id.org/ldac/terms#SpokenLanguage
# 1353  https://w3id.org/ldac/terms#WrittenLanguage
#
#      ldac:indexableText_contentSize  \
# 0                              4960
# 1                              3342
# 2                              3339
# 3                              4738
# 4                              1825
# ...                             ...
# 1349                          48257
# 1350                          28080
# 1351                          13818
# 1352                          15562
# 1353                            760
#
#                                           ldac:mainText  \
# 0     <source><g=m><o=b><age=50><status=1><abode=00>...
# 1     \n\n\n<source><g=m><o=b><age=50><status=1><abo...
# 2     \n\n\n<source><g=m><o=b><age=50><status=1><abo...
# 3     \n\n\n<source><g=m><o=b><age=50><status=1><abo...
# 4     \n\n\n<source><g=m><o=b><age=50><status=1><abo...
# ...                                                 ...
# 1349  load failed: File read failed: 'utf-8' codec c...
# 1350  load failed: File read failed: 'utf-8' codec c...
# 1351  \n\n\n<source><g=m><o=a><age=54><status=2><abo...
# 1352  \n\n\n<source><g=m><o=a><age=48><status=2><abo...
# 1353  <source><g=m><o=a><age=31><status=2><abode=nv>...
#
#      ldac:linguisticGenre_sameAs  \
# 0                           None
# 1                           None
# 2                           None
# 3                           None
# 4                           None
# ...                          ...
# 1349                        None
# 1350                        None
# 1351                        None
# 1352                        None
# 1353
#
#                          ldac:linguisticGenre_sameAs_id author_description
# 0                                                  None               None
# 1                                                  None               None
# 2                                                  None               None
# 3                                                  None               None
# 4                                                  None               None
# ...                                                 ...                ...
# 1349                                               None               None
# 1350                                               None               None
# 1351                                               None               None
# 1352                                               None               None
# 1353  http://www.language-archives.org/REC/type-2002...               None
#
# [1354 rows x 74 columns]

# %% [markdown]
# ## Getting People

# %%
text_data.columns
# Out:
# Index(['entity_id', 'name', 'author_@type', 'author_name', 'author_birthDate',
#        'author_local:birthDateEstimateStart',
#        'author_local:birthDateEstimateEnd', 'author_birthPlace',
#        'author_birthPlace_id', 'author_gender', 'author_local:arrivalDate',
#        'author_local:arrivalDateEstimateStart',
#        'author_local:arrivalDateEstimateEnd',
#        'author_local:yearsLivedInAustralia', 'author_ldac:age',
#        'author_local:socialClass', 'author_local:socialClass_id',
#        'author_prov:specializationOf', 'author_prov:specializationOf_id',
#        'description', 'dateCreated', 'register_name', 'register_description',
#        'register_@type', 'register_inDefinedTermSet',
#        'register_inDefinedTermSet_id', 'textType_name', 'textType_description',
#        'textType_@type', 'textType_inDefinedTermSet',
#        'textType_inDefinedTermSet_id', 'temporal', 'locationCreated',
#        'locationCreated_id', 'ldac:linguisticGenre_@type',
#        'ldac:linguisticGenre_name', 'ldac:linguisticGenre_description',
#        'ldac:linguisticGenre_inDefinedTermSet',
#        'ldac:linguisticGenre_inDefinedTermSet_id', 'datePublished', 'citation',
#        'citation_id', 'recipient_name', 'recipient_socialClass',
#        'recipient_socialClass_id', 'recipient_homeLocation',
#        'recipient_homeLocation_id', 'recipient_@type', 'recipient_gender',
#        'ldac:communicationMode_@type', 'ldac:communicationMode_name',
#        'ldac:communicationMode_description',
#        'ldac:communicationMode_inDefinedTermSet',
#        'ldac:communicationMode_inDefinedTermSet_id', 'inLanguage',
#        'inLanguage_id', 'ldac:indexableText_name', 'ldac:indexableText_@type',
#        'ldac:indexableText_materialType', 'ldac:indexableText_materialType_id',
#        'ldac:indexableText_ldac:annotationOf',
#        'ldac:indexableText_ldac:annotationOf_id',
#        'ldac:indexableText_inLanguage', 'ldac:indexableText_inLanguage_id',
#        'ldac:indexableText_encodingFormat',
#        'ldac:indexableText_encodingFormat_1',
#        'ldac:indexableText_encodingFormat_id',
#        'ldac:indexableText_ldac:communicationMode',
#        'ldac:indexableText_ldac:communicationMode_id',
#        'ldac:indexableText_contentSize', 'ldac:mainText',
#        'ldac:linguisticGenre_sameAs', 'ldac:linguisticGenre_sameAs_id',
#        'author_description'],
#       dtype='object')

# %% [markdown]
# ## Getting the organizations
