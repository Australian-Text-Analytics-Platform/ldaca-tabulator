# %% [markdown]
# # Example Code

# %%
from src.tabulator import LDaCATabulator

# %%
# COOEE corpus url
zip_url = "https://data.ldaca.edu.au/api/object/arcp%3A%2F%2Fname%2Chdl10.26180~23961609.zip"

ldac_tb = LDaCATabulator(zip_url)

ldac_tb.get_text()
# Out:
# 100%|██████████| 8078/8078 [00:07<00:00, 1039.13it/s]
# 100%|██████████| 1322/1322 [00:11<00:00, 119.29it/s]
# 100%|██████████| 2439/2439 [00:20<00:00, 117.93it/s]
# 100%|██████████| 13/13 [00:00<00:00, 117.67it/s]
# 100%|██████████| 1/1 [00:00<00:00, 119.64it/s]
# Dataset.hasPart > 10 relations
# Dataset.pcdm:hasMember > 10 relations
# 100%|██████████| 2/2 [00:01<00:00,  1.16it/s]
# 100%|██████████| 1/1 [00:00<00:00, 119.27it/s]
# 100%|██████████| 2713/2713 [00:23<00:00, 117.49it/s]
# 100%|██████████| 1/1 [00:00<00:00, 111.33it/s]
# 100%|██████████| 3/3 [00:00<00:00, 116.89it/s]
# 100%|██████████| 3/3 [00:00<00:00, 114.74it/s]
# 100%|██████████| 28/28 [00:00<00:00, 115.74it/s]
# 100%|██████████| 8/8 [00:00<00:00, 115.75it/s]
# 100%|██████████| 3/3 [00:00<00:00, 115.94it/s]
# RepositoryCollection.hasPart > 10 relations
# RepositoryCollection.pcdm:hasMember > 10 relations
# 100%|██████████| 1/1 [00:01<00:00,  1.72s/it]
# 100%|██████████| 32/32 [00:00<00:00, 114.90it/s]
# 100%|██████████| 1/1 [00:00<00:00, 115.05it/s]
# 100%|██████████| 1354/1354 [00:11<00:00, 115.06it/s]
# 100%|██████████| 156/156 [00:01<00:00, 116.48it/s]
# 100%|██████████| 1/1 [00:00<00:00, 118.84it/s]
# 100%|██████████| 1/1 [00:00<00:00, 111.05it/s]
# Expanding 11 properties: ['author', 'register', 'textType', 'locationCreated', 'ldac:linguisticGenre', 'citation', 'recipient', 'ldac:communicationMode', 'ldac:indexableText', 'ldac:mainText', 'hasPart']
# 100%|██████████| 1354/1354 [02:17<00:00,  9.87it/s]
#      dateCreated                                 ldac:indexableText  \
# 0           1788  Dear Sir,\nI have the pleasure of sending you ...
# 1           1788  \n\n\nMy Lord,\nAs I was unwilling to trouble ...
# 2           1788  \n\n\nThe Supply, sailing very badly, had not ...
# 3           1788  \n\n\nYour Lordship will permit me to observe ...
# 4           1788   every day proves the necessity of proper pers...
# ...          ...                                                ...
# 1349        1897  \n\n\nSir GEORGE TURNER:  \nI am pleased indee...
# 1350        1898  \n\n\nMr. LYNE. -  \nI have not seen it. But I...
# 1351        1898  \n\n\nSir JOHN DOWNER (South Australia). -  \n...
# 1352        1898  \n\n\nMr. KINGSTON. -  \nI think we must recog...
# 1353        1895  Once a jolly swagman camped by a Billabong\nUn...
#
#                                     description locationCreated  \
# 0                Text 1-001 1788 Philip, Arthur            None
# 1                Text 1-002 1788 Philip, Arthur            None
# 2                Text 1-003 1788 Philip, Arthur            None
# 3                Text 1-004 1788 Philip, Arthur            None
# 4                Text 1-005 1788 Philip, Arthur            None
# ...                                         ...             ...
# 1349             Text 4-421 1897 Turner, George            None
# 1350         Text 4-422 1898 Lyne, William John            None
# 1351       Text 4-423 1898 Downer, John William            None
# 1352  Text 4-424 1898 Kingston, Charles Cameron            None
# 1353    Text 4-425 1895 Paterson, Andrew Barton            None
#
#      ldac:communicationMode identifier   temporal recipient textType  \
# 0                      None      1-001  1788/1825      None     None
# 1                      None      1-002  1788/1825      None     None
# 2                      None      1-003  1788/1825      None     None
# 3                      None      1-004  1788/1825      None     None
# 4                      None      1-005  1788/1825      None     None
# ...                     ...        ...        ...       ...      ...
# 1349                   None      4-421  1876/1900      None     None
# 1350                   None      4-422  1876/1900      None     None
# 1351                   None      4-423  1876/1900      None     None
# 1352                   None      4-424  1876/1900      None     None
# 1353                   None      4-425  1876/1900      None     None
#
#      datePublished  ... locationCreated_name author_local:arrivalDate  \
# 0             1998  ...      New South Wales                     1788
# 1             1998  ...      New South Wales                     1788
# 2             1977  ...      New South Wales                     1788
# 3             1977  ...      New South Wales                     1788
# 4             1977  ...      New South Wales                     1788
# ...            ...  ...                  ...                      ...
# 1349          1897  ...      South Australia                     None
# 1350          1898  ...             Victoria                     None
# 1351          1898  ...             Victoria                     None
# 1352          1898  ...             Victoria                     None
# 1353          1895  ...           Queensland                     None
#
#      hasPart_inLanguage ldac:mainText_materialType  \
# 0               English            DerivedMaterial
# 1               English            DerivedMaterial
# 2               English            DerivedMaterial
# 3               English            DerivedMaterial
# 4               English            DerivedMaterial
# ...                 ...                        ...
# 1349            English            DerivedMaterial
# 1350            English            DerivedMaterial
# 1351            English            DerivedMaterial
# 1352            English            DerivedMaterial
# 1353            English            DerivedMaterial
#
#                                      citation_name  \
# 0                               Niall, 1998 p10-11
# 1                               Niall, 1998 p12-13
# 2                               Clark, 1977 p44-46
# 3                               Clark, 1977 p47-48
# 4                                  Clark, 1977 p52
# ...                                            ...
# 1349  Federation Debates Adelaide, March 24 p37-50
# 1350  Federation Debates Melbourne, Jan 24 p95-102
# 1351  Federation Debates Melbourne, Jan 24 p112-16
# 1352   Federation Debates Melbourne, Jan 24 p91-95
# 1353                                Paterson, 1895
#
#                        ldac:linguisticGenre_description citation_pageStart  \
# 0     Discourse whose primary purpose is to inform t...                 10
# 1     Discourse whose primary purpose is to inform t...                 12
# 2     Discourse whose primary purpose is to inform t...                 44
# 3     Discourse whose primary purpose is to inform t...                 47
# 4     Discourse whose primary purpose is to inform t...                 52
# ...                                                 ...                ...
# 1349  Discourse whose primary purpose is to inform t...                 37
# 1350  Discourse whose primary purpose is to inform t...                 95
# 1351  Discourse whose primary purpose is to inform t...                112
# 1352  Discourse whose primary purpose is to inform t...                 91
# 1353  The resource is a ritually or conventionally s...               None
#
#      citation_ldac:materialType hasPart_materialType hasPart_contentSize
# 0               PrimaryMaterial      DerivedMaterial                4960
# 1               PrimaryMaterial      DerivedMaterial                3342
# 2               PrimaryMaterial      DerivedMaterial                3339
# 3               PrimaryMaterial      DerivedMaterial                4738
# 4               PrimaryMaterial      DerivedMaterial                1825
# ...                         ...                  ...                 ...
# 1349            PrimaryMaterial      DerivedMaterial               48257
# 1350            PrimaryMaterial      DerivedMaterial               28080
# 1351            PrimaryMaterial      DerivedMaterial               13818
# 1352            PrimaryMaterial      DerivedMaterial               15562
# 1353            PrimaryMaterial      DerivedMaterial                 760
#
# [1354 rows x 61 columns]
