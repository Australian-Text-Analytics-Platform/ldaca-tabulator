# %%
from src.loader import expand_for_entity_types

# %% [markdown]
# # Example code

# %%
# COOEE corpus url
zip_url = "https://data.ldaca.edu.au/api/object/arcp%3A%2F%2Fname%2Chdl10.25949~24769173.v1.zip"

# Run the function
df = expand_for_entity_types(
    zip_url=zip_url,
    verbose=True  
)
