# %% [markdown]
# # Example Code

# %% [markdown]
# ## Importing packages

# %%
from src.tabulator import LDaCATabulator

# %% [markdown]
# ## Downloading corpus and decompress the folder

# %%
zip_url = "https://data.ldaca.edu.au/api/object/arcp%3A%2F%2Fname%2Chdl10.26181~23089559.zip"

ldac_tb = LDaCATabulator(zip_url)
# Out:
# 100%|██████████| 6423/6423 [00:03<00:00, 1607.87it/s]

# %% [markdown]
# ## Getting metadata and text data

# %%
text_data = ldac_tb.get_text()
text_data
# Out:
# RepositoryObject.hasPart > 10 relations
# RepositoryObject.ldac:speaker > 10 relations
# RepositoryObject.hasPart > 10 relations
# 100%|██████████| 558/558 [00:11<00:00, 48.19it/s]
# 100%|██████████| 753/753 [00:03<00:00, 200.82it/s]
#                                                   name inLanguage  \
# 0    S1A-001 : Conversation - Friendly debate in Do...    English
# 1    S1A-002 : Conversation - Dinner party:  plants...    English
# 2    S1A-003 : Conversation - 2M talking re holiday...    English
# 3    S1A-004 : Conversation - Family talking about ...    English
# 4    S1A-005 : Conversation - Family discussion re ...    English
# ..                                                 ...        ...
# 553            W2F-016 : The Last Magician - Chapter 8    English
# 554                          W2F-017 : Isobars - Bondi    English
# 555        W2F-018 : The Mule's Foal - The Mule's Foal    English
# 556                  W2F-019 : The Riders - Chapter 16    English
# 557     W2F-020 : A Change In The Lighting - Chapter 8    English
#
#     datePublished                                        description  \
# 0      1992-06-14                          Friendly debate in Domain
# 1      1991-12-01    Dinner party:  plants, buildings Gulf War, USSR
# 2      1917-05-93         2M talking re holidays in Port Douglas Qld
# 3      1992-10-14        Family talking about food, wine and romance
# 4      1992-09-19  Family discussion re restaurants, rides at fun...
# ..            ...                                                ...
# 553          None                                               None
# 554          None                                               None
# 555          None                                               None
# 556          None                                               None
# 557          None                                               None
#
#     ldac:communicationMode_@type ldac:communicationMode_name  \
# 0                    DefinedTerm              SpokenLanguage
# 1                    DefinedTerm              SpokenLanguage
# 2                    DefinedTerm              SpokenLanguage
# 3                    DefinedTerm              SpokenLanguage
# 4                    DefinedTerm              SpokenLanguage
# ..                           ...                         ...
# 553                  DefinedTerm             WrittenLanguage
# 554                  DefinedTerm             WrittenLanguage
# 555                  DefinedTerm             WrittenLanguage
# 556                  DefinedTerm             WrittenLanguage
# 557                  DefinedTerm             WrittenLanguage
#
#                     ldac:communicationMode_description  \
# 0    The resource contains data for which the mediu...
# 1    The resource contains data for which the mediu...
# 2    The resource contains data for which the mediu...
# 3    The resource contains data for which the mediu...
# 4    The resource contains data for which the mediu...
# ..                                                 ...
# 553  The resource contains data for which the mediu...
# 554  The resource contains data for which the mediu...
# 555  The resource contains data for which the mediu...
# 556  The resource contains data for which the mediu...
# 557  The resource contains data for which the mediu...
#
#     ldac:communicationMode_inDefinedTermSet ldac:linguisticGenre_@type  \
# 0                                                          DefinedTerm
# 1                                                          DefinedTerm
# 2                                                          DefinedTerm
# 3                                                          DefinedTerm
# 4                                                          DefinedTerm
# ..                                      ...                        ...
# 553                                                        DefinedTerm
# 554                                                        DefinedTerm
# 555                                                        DefinedTerm
# 556                                                        DefinedTerm
# 557                                                        DefinedTerm
#
#     ldac:linguisticGenre_name  ...                 ldac:indexableText_license  \
# 0                    Dialogue  ...  Attribution 4.0 International (CC BY 4.0)
# 1                    Dialogue  ...  Attribution 4.0 International (CC BY 4.0)
# 2                    Dialogue  ...  Attribution 4.0 International (CC BY 4.0)
# 3                    Dialogue  ...  Attribution 4.0 International (CC BY 4.0)
# 4                    Dialogue  ...  Attribution 4.0 International (CC BY 4.0)
# ..                        ...  ...                                        ...
# 553                 Narrative  ...  Attribution 4.0 International (CC BY 4.0)
# 554                 Narrative  ...  Attribution 4.0 International (CC BY 4.0)
# 555                 Narrative  ...  Attribution 4.0 International (CC BY 4.0)
# 556                 Narrative  ...  Attribution 4.0 International (CC BY 4.0)
# 557                 Narrative  ...  Attribution 4.0 International (CC BY 4.0)
#
#     ldac:indexableText_encodingFormat ldac:indexableText_encodingFormat_1  \
# 0                          text/plain
# 1                          text/plain
# 2                          text/plain
# 3                          text/plain
# 4                          text/plain
# ..                                ...                                 ...
# 553                        text/plain
# 554                        text/plain
# 555                        text/plain
# 556                        text/plain
# 557                        text/plain
#
#     ldac:indexableText_contentSize ldac:indexableText_ldac:materialType  \
# 0                            11151                           Annotation
# 1                            10673                           Annotation
# 2                             9991                           Annotation
# 3                            10219                           Annotation
# 4                            13312                           Annotation
# ..                             ...                                  ...
# 553                          11441                      PrimaryMaterial
# 554                          11645                      PrimaryMaterial
# 555                          10952                      PrimaryMaterial
# 556                          11296                      PrimaryMaterial
# 557                          11470                      PrimaryMaterial
#
#     ldac:indexableText_ldac:annotatationType  \
# 0                              Transcription
# 1                                       None
# 2                              Transcription
# 3                              Transcription
# 4                              Transcription
# ..                                       ...
# 553                                     None
# 554                                     None
# 555                                     None
# 556                                     None
# 557                                     None
#
#     ldac:indexableText_ldac:communicationMode  \
# 0                              SpokenLanguage
# 1                              SpokenLanguage
# 2                              SpokenLanguage
# 3                              SpokenLanguage
# 4                              SpokenLanguage
# ..                                        ...
# 553                           WrittenLanguage
# 554                           WrittenLanguage
# 555                           WrittenLanguage
# 556                           WrittenLanguage
# 557                           WrittenLanguage
#
#                                          ldac:mainText  \
# 0    <S1A-001> <2001>\n\n<I><$A> <#\>So you gonna b...
# 1    <S1A-002> <2009>\n<I><$A> <#\>Somewhere I was ...
# 2    <S1A-003> <2013>\n\n <I><$A> <#\>Now what I wa...
# 3    <S1A-004> <2003>\n <I><$A> <#\>Mum, we saw a f...
# 4    <S1A-005> <2014>\n <I>\n<$A> <#\>Yeah I think ...
# ..                                                 ...
# 553  <W2F-016>  <2007>\n\n<I><#\><h><bold><it>8</it...
# 554  <W2F-017>  <2010>\n\n<I><#\><h><bold><it>Bondi...
# 555  <W2F-018>  <2013>\n\n<I><#\><h><bold><smallcap...
# 556  <W2F-019>  <2016>\n\n<I><#\><h><bold><it>Sixte...
# 557  <W2F-020>  <2014>\n\n<I><#\><h><bold><it>A Cha...
#
#     ldac:linguisticGenre_sameAs speakers
# 0                          None       []
# 1                          None       []
# 2                          None       []
# 3                          None       []
# 4                          None       []
# ..                          ...      ...
# 553                                   []
# 554                                   []
# 555                                   []
# 556                                   []
# 557                                   []
#
# [558 rows x 24 columns]

# %% [markdown]
# ## Getting People

# %%
import pandas as pd
text_data.iloc[:, 19:29]
#text_data["name"][1]
# Out:
#     ldac:indexableText_ldac:annotatationType  \
# 0                              Transcription
# 1                                       None
# 2                              Transcription
# 3                              Transcription
# 4                              Transcription
# ..                                       ...
# 553                                     None
# 554                                     None
# 555                                     None
# 556                                     None
# 557                                     None
#
#     ldac:indexableText_ldac:communicationMode ldac:mainText_name  \
# 0                              SpokenLanguage        S1A-001.TXT
# 1                              SpokenLanguage        S1A-002.TXT
# 2                              SpokenLanguage        S1A-003.TXT
# 3                              SpokenLanguage        S1A-004.TXT
# 4                              SpokenLanguage        S1A-005.TXT
# ..                                        ...                ...
# 553                           WrittenLanguage        W2F-016.TXT
# 554                           WrittenLanguage        W2F-017.TXT
# 555                           WrittenLanguage        W2F-018.TXT
# 556                           WrittenLanguage        W2F-019.TXT
# 557                           WrittenLanguage        W2F-020.TXT
#
#     ldac:mainText_@type                      ldac:mainText_license  \
# 0                  File  Attribution 4.0 International (CC BY 4.0)
# 1                  File  Attribution 4.0 International (CC BY 4.0)
# 2                  File  Attribution 4.0 International (CC BY 4.0)
# 3                  File  Attribution 4.0 International (CC BY 4.0)
# 4                  File  Attribution 4.0 International (CC BY 4.0)
# ..                  ...                                        ...
# 553                File  Attribution 4.0 International (CC BY 4.0)
# 554                File  Attribution 4.0 International (CC BY 4.0)
# 555                File  Attribution 4.0 International (CC BY 4.0)
# 556                File  Attribution 4.0 International (CC BY 4.0)
# 557                File  Attribution 4.0 International (CC BY 4.0)
#
#     ldac:mainText_encodingFormat ldac:mainText_encodingFormat_1  \
# 0                     text/plain
# 1                     text/plain
# 2                     text/plain
# 3                     text/plain
# 4                     text/plain
# ..                           ...                            ...
# 553                   text/plain
# 554                   text/plain
# 555                   text/plain
# 556                   text/plain
# 557                   text/plain
#
#     ldac:mainText_contentSize ldac:mainText_ldac:materialType  \
# 0                       14890                      Annotation
# 1                       15126                      Annotation
# 2                       13512                      Annotation
# 3                       16362                      Annotation
# 4                       18992                      Annotation
# ..                        ...                             ...
# 553                     12309                 PrimaryMaterial
# 554                     13193                 PrimaryMaterial
# 555                     11617                 PrimaryMaterial
# 556                     12493                 PrimaryMaterial
# 557                     12988                 PrimaryMaterial
#
#     ldac:mainText_ldac:annotationType
# 0                       Transcription
# 1                       Transcription
# 2                       Transcription
# 3                       Transcription
# 4                       Transcription
# ..                                ...
# 553                              None
# 554                              None
# 555                              None
# 556                              None
# 557                              None
#
# [558 rows x 10 columns]

# %% [markdown]
# ## Getting the organizations

# %%
ldac_tb.corpus_specific_tables_list()
# Out:
# "Corpus-specific tables: ['Dataset', 'DefinedTerm', 'File']. Use corpus_specific_tables(table_name) to load the data."
