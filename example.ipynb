# %% [markdown]
# # Example Code

# %%
from src.tabulator import LDaCATabulator

# %%
# COOEE corpus url
zip_url = "https://data.ldaca.edu.au/api/object/arcp%3A%2F%2Fname%2Chdl10.26180~23961609.zip"

ldac_tb = LDaCATabulator(zip_url)

#df = ldac_tb.get_text()
# Out:
# 100%|██████████| 8078/8078 [00:07<00:00, 1015.53it/s]

# %%
df.columns
# Out:
# Index(['name', 'author_name', 'author_birthDate',
#        'author_local:birthDateEstimateStart',
#        'author_local:birthDateEstimateEnd', 'author_birthPlace',
#        'author_gender', 'author_local:arrivalDateEstimateStart',
#        'author_local:arrivalDateEstimateEnd',
#        'author_local:yearsLivedInAustralia', 'author_ldac:age',
#        'author_local:socialClass', 'description', 'dateCreated',
#        'register_name', 'register_inDefinedTermSet', 'textType_name',
#        'textType_inDefinedTermSet', 'temporal', 'locationCreated',
#        'ldac:linguisticGenre_name', 'ldac:linguisticGenre_inDefinedTermSet',
#        'datePublished', 'citation', 'recipient_name', 'recipient_socialClass',
#        'recipient_homeLocation', 'recipient_gender',
#        'ldac:communicationMode_name',
#        'ldac:communicationMode_inDefinedTermSet', 'inLanguage',
#        'ldac:indexableText_name', 'ldac:indexableText_materialType',
#        'ldac:indexableText_materialType_id',
#        'ldac:indexableText_ldac:annotationOf',
#        'ldac:indexableText_ldac:annotationOf_id',
#        'ldac:indexableText_encodingFormat',
#        'ldac:indexableText_encodingFormat_1',
#        'ldac:indexableText_encodingFormat_id',
#        'ldac:indexableText_ldac:communicationMode',
#        'ldac:indexableText_contentSize', 'ldac:mainText', 'hasPart'],
#       dtype='object')

# %%
ldac_tb.get_people().columns
# Out:
# 100%|██████████| 2439/2439 [00:21<00:00, 115.13it/s]
# Index(['entity_id', 'name', 'birthDate', 'local:birthDateEstimateStart',
#        'local:birthDateEstimateEnd', 'birthPlace', 'birthPlace_id', 'gender',
#        'local:arrivalDateEstimateStart', 'local:arrivalDateEstimateEnd',
#        'local:yearsLivedInAustralia', 'ldac:age', 'local:socialClass',
#        'local:socialClass_id', 'socialClass', 'socialClass_id', 'homeLocation',
#        'homeLocation_id'],
#       dtype='object')

# %%
target_types = list(tb.config["tables"])
target_types
# Out:
# ['RepositoryObject', 'Person', 'Organization', 'DefinedTerm', 'CreativeWork']

# %%
for table in ["RepositoryObject"]:
    print(f"{table}")
# Out:
# RepositoryObject
